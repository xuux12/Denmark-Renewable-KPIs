# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Owner/Desktop/renewable_energy_pipeline/data/processed/kpis.csv')

# %%
df.head(3)
# Out:
#                utc_timestamp  wind_onshore_generation  \
# 0  2014-12-31 00:00:00+00:00                      NaN
# 1  2015-01-01 00:00:00+00:00              2577.083043
# 2  2015-01-02 00:00:00+00:00              2937.597083
#
#    wind_onshore_installed_capacity  wind_onshore_capacity_factor  \
# 0                        4487.0885                           NaN
# 1                        4487.0885                      0.574333
# 2                        4487.0885                      0.654678
#
#    wind_offshore_generation  wind_offshore_installed_capacity  \
# 0                       NaN                            1700.8
# 1               1099.251304                            1700.8
# 2               1076.845833                            1700.8
#
#    wind_offshore_capacity_factor  solar_photovoltaic_generation  \
# 0                            NaN                            NaN
# 1                       0.646314                        1.64950
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2101 entries, 0 to 2100
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   utc_timestamp                          2101 non-null   object
#  1   wind_onshore_generation                2100 non-null   float64
#  2   wind_onshore_installed_capacity        2101 non-null   float64
#  3   wind_onshore_capacity_factor           2100 non-null   float64
#  4   wind_offshore_generation               2100 non-null   float64
#  5   wind_offshore_installed_capacity       2101 non-null   float64
#  6   wind_offshore_capacity_factor          2100 non-null   float64
#  7   solar_photovoltaic_generation          2100 non-null   float64
#  8   solar_photovoltaic_installed_capacity  2101 non-null   float64
#  9   solar_photovoltaic_capacity_factor     2100 non-null   float64
# dtypes: float64(9), object(1)
# ...

# %%
# Convert Timestamp Column
df['utc_timestamp'] = pd.to_datetime(df['utc_timestamp'])
df.set_index('utc_timestamp', inplace=True)

# %%
# Plot generation trends
df[['wind_onshore_generation', 'wind_offshore_generation', 'solar_photovoltaic_generation']].plot(figsize=(15, 6))
plt.title("Renewable Generation Over Time")
plt.ylabel("Generation (MWh)")
plt.show()

# %%
df.columns
# Out:
# Index(['wind_onshore_generation', 'wind_onshore_installed_capacity',
#        'wind_onshore_capacity_factor', 'wind_offshore_generation',
#        'wind_offshore_installed_capacity', 'wind_offshore_capacity_factor',
#        'solar_photovoltaic_generation',
#        'solar_photovoltaic_installed_capacity',
#        'solar_photovoltaic_capacity_factor'],
#       dtype='object')

# %%
df.head()
# Out:
#                            wind_onshore_generation  \
# utc_timestamp
# 2014-12-31 00:00:00+00:00                      NaN
# 2015-01-01 00:00:00+00:00              2577.083043
# 2015-01-02 00:00:00+00:00              2937.597083
# 2015-01-03 00:00:00+00:00              2030.766250
# 2015-01-04 00:00:00+00:00              1453.840000
#
#                            wind_onshore_installed_capacity  \
# utc_timestamp
# 2014-12-31 00:00:00+00:00                        4487.0885
# 2015-01-01 00:00:00+00:00                        4487.0885
# 2015-01-02 00:00:00+00:00                        4487.0885
# 2015-01-03 00:00:00+00:00                        4487.0885
# 2015-01-04 00:00:00+00:00                        4487.0885
#
#                            wind_onshore_capacity_factor  \
# utc_timestamp
# 2014-12-31 00:00:00+00:00                           NaN
# 2015-01-01 00:00:00+00:00                      0.574333
# 2015-01-02 00:00:00+00:00                      0.654678
# ...
